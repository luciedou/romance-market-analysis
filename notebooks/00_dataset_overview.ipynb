# %% [markdown]
# # Dataset overview
#
# This notebook explores the Goodreads dataset to understand its structure and data quality.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/Goodreads_books_with_genres.csv", encoding='latin-1', on_bad_lines='skip')
df.head()
# Out:
#                                                                                                                                                     Book Id;Title;Author;average_rating;isbn;isbn13;language_code;num_pages;ratings_count;text_reviews_count;publication_date;publisher;genres
# 1;Harry Potter and the Half-Blood Prince (Harry... 78044E+12;eng;652;2095690;27591;9/16/2006;Schol... Magic;Childrens;Adventure;Audiobook;Childrens     Middle Grade;Classics;Science Fiction Fantasy"
# 2;Harry Potter and the Order of the Phoenix (Ha... 78044E+12;eng;870;2153167;29221;9/1/2004;Schola... Magic;Childrens;Adventure;Audiobook;Childrens     Middle Grade;Classics;Science Fiction Fantasy"
# 4;Harry Potter and the Chamber of Secrets (Harr... 78044E+12;eng;352;6333;244;11/1/2003;Scholastic... Magic;Childrens;Childrens                      Middle Grade;Audiobook;Adventure;Classics;Scie...
# ...
